# %%
import numpy as np

# %%
arr = np.load('team13/strategy0-player1.npy')

# %%
arr
# Out:
# array([[8.79753831e-01, 0.00000000e+00, 1.20246169e-01],
#        [5.82750583e-04, 0.00000000e+00, 9.99417249e-01],
#        [3.33333333e-01, 3.33333333e-01, 3.33333333e-01],
#        ...,
#        [3.38308458e-01, 0.00000000e+00, 6.61691542e-01],
#        [5.00000000e-01, 0.00000000e+00, 5.00000000e-01],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00]])
